# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %%
DJI = pd.read_csv('^DJI.csv')
DJI
# Out:
#             Date          Open          High           Low         Close  \
# 0     2009-01-02   8772.250000   9065.280273   8760.780273   9034.690430
# 1     2009-01-05   9027.129883   9034.370117   8892.360352   8952.889648
# 2     2009-01-06   8954.570313   9088.059570   8940.950195   9015.099609
# 3     2009-01-07   8996.940430   8996.940430   8719.919922   8769.700195
# 4     2009-01-08   8769.940430   8770.019531   8651.190430   8742.459961
# ...          ...           ...           ...           ...           ...
# 2823  2020-03-23  19028.359375  19121.009766  18213.650391  18591.929688
# 2824  2020-03-24  19722.189453  20737.699219  19649.250000  20704.910156
# 2825  2020-03-25  21050.339844  22019.929688  20538.339844  21200.550781
# 2826  2020-03-26  21468.380859  22595.060547  21427.099609  22552.169922
# 2827  2020-03-27  21898.470703  22327.570313  21469.269531  21636.779297
#
#          Adj Close     Volume
# 0      9034.690430  213700000
# ...

# %%
DJI['Date'] = pd.to_datetime(DJI['Date'])

# %%
DJI.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume                int64
# dtype: object

# %%
GSPC = pd.read_csv('^GSPC.csv')
GSPC
# Out:
#             Date         Open         High          Low        Close  \
# 0     2009-01-02   902.989990   934.729980   899.349976   931.799988
# 1     2009-01-05   929.169983   936.630005   919.530029   927.450012
# 2     2009-01-06   931.169983   943.849976   927.280029   934.700012
# 3     2009-01-07   927.450012   927.450012   902.369995   906.650024
# 4     2009-01-08   905.729980   910.000000   896.809998   909.729980
# ...          ...          ...          ...          ...          ...
# 2823  2020-03-23  2290.709961  2300.729980  2191.860107  2237.399902
# 2824  2020-03-24  2344.439941  2449.709961  2344.439941  2447.330078
# 2825  2020-03-25  2457.770020  2571.419922  2407.530029  2475.560059
# 2826  2020-03-26  2501.290039  2637.010010  2500.719971  2630.070068
# 2827  2020-03-27  2555.870117  2615.909912  2520.020020  2541.469971
#
#         Adj Close      Volume
# 0      931.799988  4048270000
# 1      927.450012  5413910000
# 2      934.700012  5392620000
# ...

# %%
GSPC['Date'] = pd.to_datetime(GSPC['Date'])

# %%
GSPC.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume                int64
# dtype: object

# %%
IXIC = pd.read_csv('^IXIC.csv')
IXIC
# Out:
#             Date         Open         High          Low        Close  \
# 0     2009-01-02  1578.869995  1636.030029  1571.979980  1632.209961
# 1     2009-01-05  1621.479980  1640.459961  1604.630005  1628.030029
# 2     2009-01-06  1642.369995  1665.630005  1636.250000  1652.380005
# 3     2009-01-07  1621.630005  1625.369995  1588.199951  1599.060059
# 4     2009-01-08  1590.250000  1617.010010  1584.280029  1617.010010
# ...          ...          ...          ...          ...          ...
# 2823  2020-03-23  6847.279785  6984.939941  6631.419922  6860.669922
# 2824  2020-03-24  7196.149902  7418.370117  7169.859863  7417.859863
# 2825  2020-03-25  7421.359863  7671.209961  7276.399902  7384.299805
# 2826  2020-03-26  7462.209961  7809.830078  7462.209961  7797.540039
# 2827  2020-03-27  7554.250000  7716.240234  7491.140137  7502.379883
#
#         Adj Close      Volume
# 0     1632.209961  1438410000
# 1     1628.030029  1816580000
# 2     1652.380005  2137640000
# ...

# %%
IXIC['Date'] = pd.to_datetime(IXIC['Date'])

# %%
IXIC.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume                int64
# dtype: object

# %%
Swine = pd.read_csv('Swine_Flu.csv')
Swine
# Out:
#       season  year  week  age_0_4  age_5_24  age_25_49  age_25_64  age_50_64  \
# 0    2008-09  2009     1     3245      2548        NaN     2606.0        NaN
# 1    2008-09  2009     2     3142      3345        NaN     2329.0        NaN
# 2    2008-09  2009     3     3602      4597        NaN     2821.0        NaN
# 3    2008-09  2009     4     4039      6602        NaN     3215.0        NaN
# 4    2008-09  2009     5     4606      8882        NaN     4240.0        NaN
# ..       ...   ...   ...      ...       ...        ...        ...        ...
# 99   2010-11  2010    48     5045      4978     2440.0        NaN        NaN
# 100  2010-11  2010    49     5060      5867     2511.0        NaN        NaN
# 101  2010-11  2010    50     6300      7194     2847.0        NaN        NaN
# 102  2010-11  2010    51     7295      7071     3433.0        NaN        NaN
# 103  2010-11  2010    52     7478      5764     4455.0        NaN        NaN
#
# ...

# %%
Dates = pd.to_datetime(Swine.year.astype(str), format='%Y') + pd.to_timedelta(Swine.week.mul(7).astype(str) + ' days')

# %%
Dates
# Out:
# 0     2009-01-08
# 1     2009-01-15
# 2     2009-01-22
# 3     2009-01-29
# 4     2009-02-05
#          ...
# 99    2010-12-03
# 100   2010-12-10
# 101   2010-12-17
# 102   2010-12-24
# 103   2010-12-31
# Length: 104, dtype: datetime64[ns]

# %%
Swine['Date'] = Dates
Swine
# Out:
#       season  year  week  age_0_4  age_5_24  age_25_49  age_25_64  age_50_64  \
# 0    2008-09  2009     1     3245      2548        NaN     2606.0        NaN
# 1    2008-09  2009     2     3142      3345        NaN     2329.0        NaN
# 2    2008-09  2009     3     3602      4597        NaN     2821.0        NaN
# 3    2008-09  2009     4     4039      6602        NaN     3215.0        NaN
# 4    2008-09  2009     5     4606      8882        NaN     4240.0        NaN
# ..       ...   ...   ...      ...       ...        ...        ...        ...
# 99   2010-11  2010    48     5045      4978     2440.0        NaN        NaN
# 100  2010-11  2010    49     5060      5867     2511.0        NaN        NaN
# 101  2010-11  2010    50     6300      7194     2847.0        NaN        NaN
# 102  2010-11  2010    51     7295      7071     3433.0        NaN        NaN
# 103  2010-11  2010    52     7478      5764     4455.0        NaN        NaN
#
# ...

# %%
Swine_DJI = pd.merge(Swine, DJI, left_on = 'Date', right_on = 'Date')
Swine_DJI
# Out:
#       season  year  week  age_0_4  age_5_24  age_25_49  age_25_64  age_50_64  \
# 0    2008-09  2009     1     3245      2548        NaN     2606.0        NaN
# 1    2008-09  2009     2     3142      3345        NaN     2329.0        NaN
# 2    2008-09  2009     3     3602      4597        NaN     2821.0        NaN
# 3    2008-09  2009     4     4039      6602        NaN     3215.0        NaN
# 4    2008-09  2009     5     4606      8882        NaN     4240.0        NaN
# ..       ...   ...   ...      ...       ...        ...        ...        ...
# 96   2010-11  2010    47     4598      4145     2043.0        NaN        NaN
# 97   2010-11  2010    48     5045      4978     2440.0        NaN        NaN
# 98   2010-11  2010    49     5060      5867     2511.0        NaN        NaN
# 99   2010-11  2010    50     6300      7194     2847.0        NaN        NaN
# 100  2010-11  2010    52     7478      5764     4455.0        NaN        NaN
#
# ...

# %%
Swine_DJI.to_csv('Swine_DJI.csv')

# %%
print('The NA values present in Swine_DJI:\n', Swine_DJI.isnull().sum(), '\n')
print('The data types in Swine_DJI:\n', Swine_DJI.dtypes, '\n')
print('The data shape of Swine_DJI:\n', Swine_DJI.shape, '\n')
# Out:
# The NA values present in Swine_DJI:
#  season                0
# year                  0
# week                  0
# age_0_4               0
# age_5_24              0
# age_25_49            39
# age_25_64            62
# age_50_64           101
# age_65                0
# ilitotal              0
# total_patients        0
# num_of_providers      0
# unweighted_ili        0
# weighted_ili          0
# Date                  0
# Open                  0
# High                  0
# Low                   0
# Close                 0
# Adj Close             0
# Volume                0
# dtype: int64
#
# The data types in Swine_DJI:
#  season                      object
# year                         int64
# week                         int64
# age_0_4                      int64
# age_5_24                     int64
# age_25_49                  float64
# age_25_64                  float64
# age_50_64                  float64
# age_65                       int64
# ...

# %%
Swine_GSPC = pd.merge(Swine, GSPC, left_on = 'Date', right_on = 'Date')
Swine_GSPC
# Out:
#       season  year  week  age_0_4  age_5_24  age_25_49  age_25_64  age_50_64  \
# 0    2008-09  2009     1     3245      2548        NaN     2606.0        NaN
# 1    2008-09  2009     2     3142      3345        NaN     2329.0        NaN
# 2    2008-09  2009     3     3602      4597        NaN     2821.0        NaN
# 3    2008-09  2009     4     4039      6602        NaN     3215.0        NaN
# 4    2008-09  2009     5     4606      8882        NaN     4240.0        NaN
# ..       ...   ...   ...      ...       ...        ...        ...        ...
# 96   2010-11  2010    47     4598      4145     2043.0        NaN        NaN
# 97   2010-11  2010    48     5045      4978     2440.0        NaN        NaN
# 98   2010-11  2010    49     5060      5867     2511.0        NaN        NaN
# 99   2010-11  2010    50     6300      7194     2847.0        NaN        NaN
# 100  2010-11  2010    52     7478      5764     4455.0        NaN        NaN
#
# ...

# %%
Swine_GSPC.to_csv('Swine_GSPC.csv')

# %%
print('The NA values present in Swine_GSPC:\n', Swine_GSPC.isnull().sum(), '\n')
print('The data types in Swine_GSPC:\n', Swine_GSPC.dtypes, '\n')
print('The data shape of Swine_GSPC:\n', Swine_GSPC.shape, '\n')
# Out:
# The NA values present in Swine_GSPC:
#  season                0
# year                  0
# week                  0
# age_0_4               0
# age_5_24              0
# age_25_49            39
# age_25_64            62
# age_50_64           101
# age_65                0
# ilitotal              0
# total_patients        0
# num_of_providers      0
# unweighted_ili        0
# weighted_ili          0
# Date                  0
# Open                  0
# High                  0
# Low                   0
# Close                 0
# Adj Close             0
# Volume                0
# dtype: int64
#
# The data types in Swine_GSPC:
#  season                      object
# year                         int64
# week                         int64
# age_0_4                      int64
# age_5_24                     int64
# age_25_49                  float64
# age_25_64                  float64
# age_50_64                  float64
# age_65                       int64
# ...

# %%
Swine_IXIC = pd.merge(Swine, IXIC, left_on = 'Date', right_on = 'Date')
Swine_IXIC
# Out:
#       season  year  week  age_0_4  age_5_24  age_25_49  age_25_64  age_50_64  \
# 0    2008-09  2009     1     3245      2548        NaN     2606.0        NaN
# 1    2008-09  2009     2     3142      3345        NaN     2329.0        NaN
# 2    2008-09  2009     3     3602      4597        NaN     2821.0        NaN
# 3    2008-09  2009     4     4039      6602        NaN     3215.0        NaN
# 4    2008-09  2009     5     4606      8882        NaN     4240.0        NaN
# ..       ...   ...   ...      ...       ...        ...        ...        ...
# 96   2010-11  2010    47     4598      4145     2043.0        NaN        NaN
# 97   2010-11  2010    48     5045      4978     2440.0        NaN        NaN
# 98   2010-11  2010    49     5060      5867     2511.0        NaN        NaN
# 99   2010-11  2010    50     6300      7194     2847.0        NaN        NaN
# 100  2010-11  2010    52     7478      5764     4455.0        NaN        NaN
#
# ...

# %%
Swine_IXIC.to_csv('Swine_IXIC.csv')

# %%
print('The NA values present in Swine_IXIC:\n', Swine_IXIC.isnull().sum(), '\n')
print('The data types in Swine_IXIC:\n', Swine_IXIC.dtypes, '\n')
print('The data shape of Swine_IXIC:\n', Swine_IXIC.shape, '\n')
# Out:
# The NA values present in Swine_IXIC:
#  season                0
# year                  0
# week                  0
# age_0_4               0
# age_5_24              0
# age_25_49            39
# age_25_64            62
# age_50_64           101
# age_65                0
# ilitotal              0
# total_patients        0
# num_of_providers      0
# unweighted_ili        0
# weighted_ili          0
# Date                  0
# Open                  0
# High                  0
# Low                   0
# Close                 0
# Adj Close             0
# Volume                0
# dtype: int64
#
# The data types in Swine_IXIC:
#  season                      object
# year                         int64
# week                         int64
# age_0_4                      int64
# age_5_24                     int64
# age_25_49                  float64
# age_25_64                  float64
# age_50_64                  float64
# age_65                       int64
# ...
